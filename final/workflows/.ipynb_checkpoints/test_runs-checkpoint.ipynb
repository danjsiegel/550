# %%
from tasks.task1 import task1
import pandas as pd
import os

# %%
dds = task1('C:\\Users\\Dan Siegel\\Desktop\\Classes\\550\\final\\data\\raw\\', 'C:\\Users\\Dan Siegel\\Desktop\\Classes\\550\\final\\data\\processed\\','controversial-comments.jsonl')

# %%
dds
# Out:
#                             cat  \
# 125352              video_games
# 1026667                  sports
# 1816399             video_games
# 516688              video_games
# 1273843                  sports
# 1570210                    news
# 1424206                    news
# 2006149  science_and_technology
# 2119561                    news
# 2213613                    news
# 131510              video_games
# 1343778                  sports
# 1658262                  sports
# 1799334  science_and_technology
# 1623723                  sports
# 400871              video_games
# 696491              video_games
# 799923   science_and_technology
# 1871704                  sports
# 1851458                  sports
# 859112              video_games
# 263628                   sports
# 658093              video_games
# 886364              video_games
# 1227262                  sports
# 1161710             video_games
# 1244653                  sports
# 2209820                    news
# 945895                   sports
# 1587079                    news
# ...                         ...
# 1863014                  sports
# 82897               video_games
# 1612400                  sports
# 2147736                    news
# 2193887                    news
# 1669986                  sports
# 1163196             video_games
# 511372              video_games
# 792762   science_and_technology
# 49022                    sports
# 571000              video_games
# 481155              video_games
# 2287668             video_games
# 409041              video_games
# 2146153                    news
# 746178              video_games
# 1577254                    news
# 98011                    sports
# 1336691                  sports
# 974096                   sports
# 252552                   sports
# 1421987                    news
# 1163735             video_games
# 1623464                  sports
# 175727              video_games
# 2062154                    news
# 1474732                    news
# 1074736             video_games
# 2033041  science_and_technology
# 1146493             video_games
#
#                                                        txt
# 125352              We'll likely know the truth tommorrow.
# 1026667  No I was talking about the Leafs player trying...
# 1816399                  Lol I did that the first time too
# 516688   Even higher if you have 6 lucios ult at the sa...
# 1273843              He is pretty good on defense actually
# 1570210  I'm not saying you're evil. I was raised by wo...
# 1424206  The swamp is a lie. There was no swamp. Surpri...
# 2006149  Hello! Unfortunately, since [your account has ...
# 2119561                                          [deleted]
# 2213613  Israel got a friend in WH again. Fuck Kerry/Ob...
# 131510   &gt;Loads of fun in Strikes\n\nUnderstatement ...
# 1343778  Yea. the big game between the high schools is ...
# 1658262                                          holy shit
# 1799334                                          [removed]
# 1623723                 How did Atlanta even lose 5 games?
# 400871   I love seeing so many people repeat the "they ...
# 696491   I'm sure he can still play offline. They can't...
# 799923                                           [removed]
# 1871704  You don't still really think that Labour is "f...
# 1851458  Berahino has to be thrown on before the 70 min...
# 859112                      My theories don't play, hehe.
# 263628   It's weird cause I have been consistently hold...
# 658093                                         There up m8
# 886364   maybe it shouldn't be disregarded, but we shou...
# 1227262  That's true, forgot. Really it was just a flat...
# 1161710                                 you dropped this \
# 1244653  His jumper makes MCW and Rondo look like Steph...
# 2209820  Yeah. I've been read by through a bit and I un...
# 945895           HUDLER SCORES! HIS THIRD GOAL OF THE YEAR
# 1587079  If you were being threatened how would you res...
# ...                                                    ...
# 1863014  Lazy run back from the black dude. Sped up at ...
# 82897                                So a pekka basically?
# 1612400            That was a pretty nice dismantling lol.
# 2147736  If it only where that simple. If the people do...
# 2193887  You are very misinformed and I feel pity for you.
# 1669986  I really can't emphasize how thoroughly he wor...
# 1163196                  He has been like that for years.
# 511372   How did it feel when you unwrapped your shiny ...
# 792762   Good news: Overcast 3 will have a feature to p...
# 49022                   Instead of going 9-4, we'd go 4-9.
# 571000                                           [deleted]
# 481155            The BOTW trailer from the January reveal
# 2287668  She can see future. It's just that apparently ...
# 409041   That's fucking adorable as shit. Gotta love th...
# 2146153             This would be a good job for the army.
# 746178           yeah. Does he have a sister named Kattie?
# 1577254  You mean Milo, a victim of molestation. You ha...
# 98011    1.0 Accuracy and Reporting\n1.1 Publications s...
# 1336691                           Tendies are pretty nice
# 974096   They put 7 SOGs in 2 minutes. Another ruined s...
# 252552                                               Juan?
# 1421987  As long as you don't know that's how you're go...
# 1163735  Very hit or miss and very binary\n\nThink of w...
# 1623464  Really nice guy and also like a HS kid lol.  T...
# 175727                                           [deleted]
# 2062154  Well, Canadian and white is good, but gay make...
# 1474732                           What about road crashes?
# 1074736                                          [removed]
# 2033041                                          [removed]
# 1146493                     I'm sure you're already there
#
# [46950 rows x 2 columns]

# %%
from tasks.task2 import task2

# %%
sdd=task2(dds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2effdfe31166> in <module>()
# ----> 1 sdd=task2(dds)
#
# ~\Desktop\Classes\550\final\workflows\tasks\task2.py in task2(corpus)
#      13         cleaned dataframe
#      14     '''
# ---> 15     corpus['cleaned'] =corpus['txt'].apply(text_processing)
#      16     return corpus
#      17
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ~\Desktop\Classes\550\final\workflows\tasks\task2.py in text_processing(mess)
#      21     nopunc = nopunc.lower()
#      22     no_stopwords = [word for word in nopunc.split() if word not in stopwords.words('english')]
# ---> 23     stemmer = PorterStemmer()
#      24     no_stopwords = [stemmer.stem(word) for word in no_stopwords]
#      25     stemmed_no_stopwords = ' '.join(no_stopwords)
#
# NameError: name 'PorterStemmer' is not defined
